# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data visualisation for car_crashes

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# # **Scatterplot**

# %%
sns.scatterplot(x="total", y="speeding", data=df)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %% [markdown]
# **inference: from the plot we can say that as speeding increases total crashes is also increasing**

# %%
sns.scatterplot(x="total", y="alcohol", data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
#  **inference: from the plot we can say that as alcohol consumption increases total crashes is also increasing**

# %% [markdown]
# ## **## Line Graph**

# %%
sns.lineplot(x="total", y="not_distracted",data=df)
# Out:
# <Axes: xlabel='total', ylabel='not_distracted'>

# %% [markdown]
# **inference: from the plot we can say that as not_distracted increases total crashes is also increasing**

# %%
sns.lineplot(x="total", y="not_distracted", data=df, linestyle="--", color='green')
plt.xlabel('Total Crashes')
plt.ylabel('Not Distracted Crashes')
plt.title('Line Plot of Not Distracted Crashes vs. Total Crashes')
plt.show()

# %% [markdown]
# **inference: from the plot we can say that as not_Distracted increases total crashes is also increasing**

# %% [markdown]
# # **Distplot**

# %%
sns.distplot(df["speeding"])
# Out:
# <ipython-input-39-8ecb7fd34a3c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["speeding"])
# <Axes: xlabel='speeding', ylabel='Density'>

# %% [markdown]
# **inference: from the plot we can say that speeding is high at 5**

# %% [markdown]
# # **Replot**

# %%
sns.relplot(x="total", y="speeding", data=df , hue="ins_losses")

# %% [markdown]
# **inference: from the plot we can say that as speeding increases total crashes is also increasing**

# %%
sns.relplot(x="alcohol", y="speeding", data=df , hue="total")

# %% [markdown]
# **inference: from the plot we can say that as speeding increases alcohol is also increasing**

# %%
df["total"].value_counts()
# Out:
# 14.1    2
# 12.8    2
# 13.6    2
# 21.4    2
# 19.4    2
# 23.9    2
# 14.9    1
# 14.7    1
# 11.6    1
# 11.2    1
# 18.4    1
# 12.3    1
# 16.8    1
# 19.9    1
# 17.6    1
# 18.2    1
# 11.1    1
# 19.5    1
# 11.3    1
# 12.7    1
# 10.6    1
# 23.8    1
# 13.8    1
# 16.1    1
# 18.8    1
# 9.6     1
# 18.1    1
# 18.6    1
# 22.4    1
# 12.0    1
# 10.8    1
# 16.2    1
# 5.9     1
# 17.9    1
# 15.6    1
# 17.5    1
# 15.3    1
# 14.5    1
# 15.7    1
# 17.8    1
# 20.5    1
# 15.1    1
# 12.5    1
# 8.2     1
# 17.4    1
# Name: total, dtype: int64

# %% [markdown]
# # **Jointplot**

# %%
sns.jointplot(x="total",y="speeding",data=df)

# %% [markdown]
# **inference: from the plot we can say that as speeding and total crashes are increased at (12.5 , 4.1)**

# %% [markdown]
# # **Boxplot**

# %%
sns.boxplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# **inference: from the plot we can say that as alcohol increases total crashes is also increasing**

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-46-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %% [markdown]
# # **BarChart**

# %%
df= df.sort_values(by='total', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='abbrev', y='total', data=df, palette='viridis')
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %% [markdown]
# **inference: from the plot we can say that as abbrev 'SC' have higher total crashes among the remaining abbrev and the least one is 'DC'**

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.xlabel("Alcohol")
plt.ylabel("Insurance Losses")
plt.title("bar Plot of Alcohol vs. Insurance Losses")
plt.bar(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("bar Plot of Alcohol vs. Insurance Losses")
plt.barh(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("bar Plot of Alcohol vs. Insurance Losses")
plt.barh(x,y,color='pink')
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("bar Plot of Alcohol vs. Insurance Losses")
plt.bar(x,y,width=0.1)
# Out:
# <BarContainer object of 51 artists>

# %%
sns.barplot(df['alcohol'])
plt.show()

# %% [markdown]
# **inference: from the plot we can say that alcohol is just below the 5**

# %%
sns.barplot(df['speeding'])
plt.show()

# %% [markdown]
# **inference: from the plot we can say that speeding is equal to 5**

# %%
sns.barplot(df['ins_losses'])
plt.show()

# %% [markdown]
# **inference: from the plot we can say that ins_losses is at 137**

# %%
sns.barplot(x='abbrev', y='alcohol', data=df, palette='pink')
sns.barplot(x='abbrev', y='speeding', data=df, color='skyblue')
plt.show()

# %% [markdown]
# **inference: Here we plot the mixed bar graph of abbrev,alochol & abbrev,speeding**

# %% [markdown]
# # **## Histogram**

# %%
plt.hist(df['alcohol'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(df['total'])
plt.xlabel('Total Crashes')
plt.title('Histogram of Total Crashes')
plt.show()

# %% [markdown]
# **inference: from the plot we can say that total crashes are high at 12.5 & equal at 15,17.5**

# %%
sns.histplot(df['speeding'])
plt.show()

# %% [markdown]
# **inference: from the plot we can say that speeding is very high in between 4,5**

# %% [markdown]
# # **PieChart**

# %%
total_speeding_crashes = df['speeding'].sum()
total_alcohol_crashes = df['alcohol'].sum()
labels = ['Speeding Crashes', 'Alcohol-Related Crashes']
sizes = [total_speeding_crashes, total_alcohol_crashes]
colors = ['lightgreen', 'violet']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Speeding and Alcohol-Related Crashes')
plt.show()

# %% [markdown]
# **inference: from the pie chart we can say that as speeding crashes slightly greater than the Alcohol related Crashes**

# %%
total_speeding_crashes = df['speeding'].sum()
total_alcohol_crashes = df['alcohol'].sum()
total_other_crashes = df['total'].sum() - (total_speeding_crashes + total_alcohol_crashes)
labels = ['Speeding Crashes', 'Alcohol-Related Crashes', 'Other Crashes']
sizes = [total_speeding_crashes, total_alcohol_crashes, total_other_crashes]
colors = ['skyblue', 'violet', 'lightgreen']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Crashes by Category')
plt.show()

# %% [markdown]
# **inference: from the plot we can say that as other reason crashes greater than the Alcohol related Crashes & speeding crashes. Speeding crashes slightly greater than the Alcohol related Crashes**

# %%
total_speeding_crashes = df['speeding'].sum()
total_alcohol_crashes = df['alcohol'].sum()
total_other_crashes = df['total'].sum() - (total_speeding_crashes + total_alcohol_crashes)
labels = ['Speeding Crashes', 'Alcohol-Related Crashes', 'Other Crashes']
sizes = [total_speeding_crashes, total_alcohol_crashes, total_other_crashes]
colors = ['skyblue', 'violet', 'lightgreen']
Explode=[0.1,0,0.2]
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=Explode)
plt.title('Distribution of Crashes by Category')
plt.show()

# %% [markdown]
# **inference: from the plot we can say that as other reason crashes greater than the Alcohol related Crashes & speeding crashes. Speeding crashes slightly greater than the Alcohol related Crashes. Here i explode the higher crashes at 0.2 and other one at 0.1 and the least one at same position.**

# %% [markdown]
# **inference: from the plot we can say that as other reason crashes greater than the Alcohol related Crashes & speeding crashes. Speeding crashes slightly greater than the Alcohol related Crashes. Here the higher crashes only explode at 0.1.**

# %%
sns.barplot(data=df,x="speeding",y="ins_losses")
# Out:
# <Axes: xlabel='speeding', ylabel='ins_losses'>

# %%
sns.barplot(data=df,x="ins_losses",y="speeding")
# Out:
# <Axes: xlabel='ins_losses', ylabel='speeding'>

# %% [markdown]
# # **## Heatmap**

# %%
df.corr()
corr=df.corr()
corr
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-27-d6f57e9457eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# <ipython-input-27-d6f57e9457eb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %% [markdown]
# **inference: from the plot we can say that >0.5 is highly correlated <0.5 is less correlated**
